# %%
from src.tokenizers.BPE_v2 import BytePairEncoding

from src.utils import paths

tokenizer = BytePairEncoding.from_file(
    path = paths.EXPERIMENTS_DIR / "gpt2-test-large/BPE_vocab_48k"
)

# %%
with open(paths.DATA_DIR / "CLASSLA-web.hr.2.0.jsonl", encoding="utf-8") as f:
    import json
    for line in f:
        obj = json.loads(line)
        print(obj["text"])
        print(tokenizer.tokenize(obj["text"]))        
        break
